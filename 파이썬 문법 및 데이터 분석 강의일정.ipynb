# %%
import pandas as pd

# %%
df = pd.read_excel("./세부 교육 내용.xlsx", date_parser=['회차'])

# %%
df = df.fillna("")

# %%
df
# Out:
#                      회차                            주요 내용         비고(시간)
# 0   2020-08-08 00:00:00     핀테크 서비스 개발을 위한 파이썬 프로그래밍 (1)  09:00 ~ 12:00
# 1                                             - 변수 , 연산자
# 2                                     -  주요 문장 :제어문, 순환문
# 3                           핀테크 서비스 개발을 위한 파이썬 프로그래밍 (2)  13:00 ~ 18:00
# 4                               - 기본 자료형:  리스트, 튜플, 딕셔너리
# 5   2020-08-15 00:00:00     핀테크 서비스 개발을 위한 파이썬 프로그래밍 (3)  09:00 ~ 12:00
# 6                        - 함수 알아보기 : 함수정의, 매개변수 할당, 익명함수
# 7                           핀테크 서비스 개발을 위한 파이썬 프로그래밍 (4)  13:00 ~ 18:00
# 8                                - 데코레이터 : 클로저, 데코레이터 기법
# 9   2020-08-22 00:00:00     핀테크 서비스 개발을 위한 파이썬 프로그래밍 (5)  09:00 ~ 12:00
# 10                       - 클래스 알아보기 ; 클래스 정의, 다양한 메소드 정의
# 11                          핀테크 서비스 개발을 위한 파이썬 프로그래밍 (6)  13:00 ~ 18:00
# 12                                    - 프로퍼티, 디스크립터 알아보기
# ...
