# %% [markdown]
# ## 따라해보기 예제  :  연속적인 숫자 덧셈과 곱셈 처리

# %%
def sigma(n) :
    if n in [0] :
        return 0
    return n + sigma(n-1)

# %%
sigma(10)
# Out:
# 55

# %%
def pie(n) :
    if n in [0,1] :
        return 1
    return n * pie(n-1)

# %%
pie(3)
# Out:
# 6

# %%
def sigma_(n,accum=0) :
    if n in [0] :
        return accum
    return sigma_(n-1, n+ accum)

# %%
sigma_(10)
# Out:
# 55

# %%
def pie_(n, accum= 1) :
    if n in [0,1] :
        return accum
    return pie(n-1, n*accum)

# %%
pie_(3)
# Out:
# 6

# %%
class Sigma :
    def __init__(self, expr) :
        self._expr = expr
        
    def sigma(self) :
        
        def inner(self,n,accum= 0) :
            if n in [0] :
                accum= accum + eval(self._expr)
                return accum
            else :
                return inner(self,n-1, (accum + eval(self._expr)))
        
        return inner

# %%
s = Sigma("2*n+1")

# %%
s.sigma()(s,10)
# Out:
# 121
