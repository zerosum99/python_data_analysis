# %% [markdown]
# # 교재

# %%
from IPython.display import Image

# %%
Image("./이미지/파이썬입문책표지.png", width=300, height=200)

# %% [markdown]
# ## 파이썬 버전 확인

# %%
# !python --version
# Out:
# Python 3.7.7

# %% [markdown]
# # 1. 예약어와 변수

# %% [markdown]
# ## 1-1 예약어 알아보기
#
# - 파이썬 언어에서 특정한 목적으로 사용하는 이름을 예약어라 한다

# %% [markdown]
# ### 예약어를 관리하는 모듈을 import 한다

# %%
import keyword

# %% [markdown]
# ### 예약어의 개수는 len 함수로 확인할 수 있다

# %%
len(keyword.kwlist)
# Out:
# 35

# %% [markdown]
# ### 실제 예약어를 확인한다

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %% [markdown]
# ## 1-2 변수(Variables) 란
#
# -  프로그램을 작성할 때 특정 값을 보관하는 영역을 지정
# - 예약어를 제외한 이름으로 지정
# - 변수의 이름은 문자와 언더스코어(_) 만 첫글자로 올 수 있다

# %% [markdown]
# ### 파이썬 언어에서 변수를 지정하면 항상 값을 할당해야 한다

# %%
variables = 1

# %% [markdown]
# ### 예약어를 변수로 지정하면 문법 에러가 발생한다

# %%
with = 1
# Out:
#   File "<ipython-input-9-fca67dd73332>", line 1
#     with = 1
#          ^
# SyntaxError: invalid syntax

# %%
Image("./이미지/변수.png", width=500, height=500)

# %%
a = 2

# %%
a
# Out:
# 2

# %%
a = a + 1

# %%
a
# Out:
# 3

# %%
b = 2

# %%
b
# Out:
# 2

# %% [markdown]
# ## 1-3 변수가 저장되는 영역(Namespace) 확인
#
# - 모듈일 경우는 글로벌 영역에 저장됨

# %%
Image("./이미지/네임스페이스.png", width=500, height=500)

# %% [markdown]
# ### 파이썬의 자료형을 확인할 때는 type을 사용

# %%
type(globals())
# Out:
# dict

# %%
spam = 100

# %%
eggs = 200

# %% [markdown]
# ### 변수의 이름으로 조회하면 내부에 저장된 값을 조회한다

# %%
globals()['spam']
# Out:
# 100

# %% [markdown]
# ###  변수의 이름으로 조회하면 글로벌 영역에 저장된 것을 바로 조회한다

# %%
spam
# Out:
# 100
